# %%
import pandas as pd
import numpy as np
import openpyxl
from tabulate import tabulate

# %%
df = pd.read_excel('data/materials.xlsx', index_col=0)
df = df.sort_values(by='mass').reset_index()
df
# Out:
#     fomula    mass  abundance
# 0        H    1.00      99.90
# 1       H2    2.01      99.98
# 2        C   12.00      98.90
# 3       CH   13.00      98.89
# 4        N   14.00      99.63
# ..     ...     ...        ...
# 69  SiHCl3  133.89      40.11
# 70    CCl4  151.87      32.59
# 71   C2Cl4  163.87      32.23
# 72   SiCl4  167.85      30.39
# 73  Si2Cl6  265.76      16.00
#
# [74 rows x 3 columns]

# %%
# assign data
mydata = zip(df['fomula'].values, df['mass'].values, df['abundance'].values)

# create header
head = ['fomular', 'mass', 'abundance']

# display table
print(tabulate(mydata, headers=head, tablefmt="grid"))
# Out:
# +-----------+--------+-------------+
# | fomular   |   mass |   abundance |
# +===========+========+=============+
# | H         |   1    |       99.9  |
# +-----------+--------+-------------+
# | H2        |   2.01 |       99.98 |
# +-----------+--------+-------------+
# | C         |  12    |       98.9  |
# +-----------+--------+-------------+
# | CH        |  13    |       98.89 |
# +-----------+--------+-------------+
# | N         |  14    |       99.63 |
# +-----------+--------+-------------+
# | NH        |  15.01 |       99.62 |
# +-----------+--------+-------------+
# | CH3       |  15.02 |       98.87 |
# +-----------+--------+-------------+
# | O         |  15.99 |       99.76 |
# +-----------+--------+-------------+
# | NH2       |  16.01 |       99.61 |
# +-----------+--------+-------------+
# | CH4       |  16.03 |       98.86 |
# +-----------+--------+-------------+
# | OH        |  17    |       99.75 |
# +-----------+--------+-------------+
# ...
